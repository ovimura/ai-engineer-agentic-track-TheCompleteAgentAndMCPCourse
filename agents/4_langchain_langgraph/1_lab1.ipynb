# %% [markdown]
# # Welcome to Week 4 - LangChain and LangGraph
#
# ## Lab 1: Abstraction Levels and the building blocks

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The LangChain docs</h2>
#             <span style="color:#00bfff;">The documentation lives at <a href="https://docs.langchain.com/oss/python/">https://docs.langchain.com/oss/python/</a>. It is worth a browse. Watch out for older 0.x material that still floats around the web, because the modern API is quite different.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## The four levels of abstraction
#
# LangChain and LangGraph form 4 levels of abstraction, with each one built on the ones before. The terminology is confusing because 'LangChain' appears in a few places..
#
# | Layer | Packages | What it gives you | What you control |
# |---|---|---|---|
# | 1. Building blocks | `langchain-core` + `langchain-openai` | chat models, the `@tool` decorator, messages, structured output | everything, including the tool loop by hand |
# | 2. Orchestration | `langgraph` | a graph of steps, with state, memory and checkpointing | the control flow (you design the graph) |
# | 3. Agent | `langchain` (`create_agent`) | the standard agent loop, prebuilt | just model, tools and a prompt |
# | 4. Harness | `deepagents` (`create_deep_agent`) | an opinionated harness with planning, sub-agents and a filesystem | your intent |
#
#
# ## Order of play for this week:
#
# DAY 1 (today): The building blocks
# DAY 2: LangGraph
# DAY 3: LangChain create_agent
# DAY 4: Deep Agents
# DAY 5: The Sidekick project

# %% [markdown]
# ## Today is Layer 1: the building blocks
#
# This is where LangChain began: an abstraction layer, not unlike LiteLLM - but a more heavyweight version.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage
from langchain_core.tools import tool
from pydantic import BaseModel, Field

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### A first model call
#
# `ChatOpenAI` is the abstraction around OpenAI calls, and there are similar packages for other LLM providers.
#
# We call `invoke` with a prompt; this is a key method in LangChain.

# %%
llm = ChatOpenAI(model="gpt-5.4-mini")

message = "In 1 sentence, what does it mean for an AI Agent to be autonomous"

reply = llm.invoke(message)

print(reply.content)
# Out:
# An AI agent is autonomous if it can independently perceive its environment, make decisions, and take actions to achieve goals without constant human direction.

# %% [markdown]
# ### Streaming
#
# For a live, token by token feel, swap `invoke` for `stream` and loop over the chunks

# %%
for chunk in llm.stream("Tell me a two line poem about autonomous agents"):
    print(chunk.content, end="", flush=True)
# Out:
# Silent minds in endless loops, they roam and learn at speed,
# Autonomous agents bloom where intent and action meet.

# %% [markdown]
# ### Any OpenAI-compatible provider
#
# As before; we can use OpenAI compatible endpoints with the ChatOpenAI object

# %%
openrouter_llm = ChatOpenAI(
    model="anthropic/claude-haiku-4.5",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

reply = openrouter_llm.invoke("In one sentence, what is LangChain?")
print(reply.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1880, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1879 else:
# -> 1880     raw_response = self.client.with_raw_response.create(**payload)
#    1881     response = raw_response.parse()
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1295 validate_response_format(response_format)
# -> 1296 return self._post(
#    1297     "/chat/completions",
#    1298     body=maybe_transform(
#    1299         {
#    1300             "messages": messages,
#    1301             "model": model,
#    1302             "audio": audio,
#    1303             "frequency_penalty": frequency_penalty,
#    1304             "function_call": function_call,
#    1305             "functions": functions,
#    1306             "logit_bias": logit_bias,
#    1307             "logprobs": logprobs,
#    1308             "max_completion_tokens": max_completion_tokens,
#    1309             "max_tokens": max_tokens,
#    1310             "metadata": metadata,
#    1311             "modalities": modalities,
#    1312             "moderation": moderation,
#    1313             "n": n,
#    1314             "parallel_tool_calls": parallel_tool_calls,
#    1315             "prediction": prediction,
#    1316             "presence_penalty": presence_penalty,
#    1317             "prompt_cache_key": prompt_cache_key,
#    1318             "prompt_cache_options": prompt_cache_options,
#    1319             "prompt_cache_retention": prompt_cache_retention,
#    1320             "reasoning_effort": reasoning_effort,
#    1321             "response_format": response_format,
#    1322             "safety_identifier": safety_identifier,
#    1323             "seed": seed,
#    1324             "service_tier": service_tier,
#    1325             "stop": stop,
#    1326             "store": store,
#    1327             "stream": stream,
#    1328             "stream_options": stream_options,
#    1329             "temperature": temperature,
#    1330             "tool_choice": tool_choice,
#    1331             "tools": tools,
#    1332             "top_logprobs": top_logprobs,
#    1333             "top_p": top_p,
#    1334             "user": user,
#    1335             "verbosity": verbosity,
#    1336             "web_search_options": web_search_options,
#    1337         },
#    1338         completion_create_params.CompletionCreateParamsStreaming
#    1339         if stream
#    1340         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341     ),
#    1342     options=make_request_options(
#    1343         extra_headers=extra_headers,
#    1344         extra_query=extra_query,
#    1345         extra_body=extra_body,
#    1346         timeout=timeout,
#    1347         security={"bearer_auth": True},
#    1348     ),
#    1349     cast_to=ChatCompletion,
#    1350     stream=stream or False,
#    1351     stream_cls=Stream[ChatCompletionChunk],
#    1352 )
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1147     log.debug("Re-raising status error")
# -> 1148     raise self._make_status_error_from_response(err.response) from None
#    1150 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIAuthenticationError                 Traceback (most recent call last)
# Cell In[4], line 7
#       3     base_url="https://openrouter.ai/api/v1",
#       4     api_key=os.getenv("OPENROUTER_API_KEY"),
#       5 )
#       6
# ----> 7 reply = openrouter_llm.invoke("In one sentence, what is LangChain?")
#       8 print(reply.content)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1885, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1883     _handle_openai_bad_request(e)
#    1884 except openai.APIError as e:
# -> 1885     _handle_openai_api_error(e)
#    1886 except Exception as e:
#    1887     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:654, in _handle_openai_api_error(e)
#     650     raise OpenAIAPIContextOverflowError(
#     651         message=e.message, request=e.request, body=e.body
#     652     ) from e
#     653 if isinstance(e, openai.AuthenticationError):
# --> 654     raise OpenAIAuthenticationError(
#     655         message=e.message, response=e.response, body=e.body
#     656     ) from e
#     657 if isinstance(e, openai.PermissionDeniedError):
#     658     raise OpenAIPermissionDeniedError(
#     659         message=e.message, response=e.response, body=e.body
#     660     ) from e
#
# OpenAIAuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ### Messages
#
# LangChain comes with abstractions around SystemMessage, HumanMessage, AIMessage, although you can use the usual list-of-dicts instead.

# %%
messages = [
    SystemMessage("You are a terse assistant who answers in exactly five words."),
    HumanMessage("What is the capital of France?"),
]

print(llm.invoke(messages).content)

# The exact same call using plain dictionaries, the format you already know
messages_as_dicts = [
    {"role": "system", "content": "You are a terse assistant who answers in exactly five words."},
    {"role": "user", "content": "What is the capital of France?"},
]
print(llm.invoke(messages_as_dicts).content)
# Out:
# Paris is France’s capital city.
# Paris is France’s capital city.

# %% [markdown]
# ### Tools with the `@tool` decorator
#
# A tool is a Python function the model is allowed to call. The modern way to make one is the `@tool` decorator. Your docstring becomes the description the model reads, and your type hints become the argument schema, just like `@function_tool` with OpenAI Agents SDK.
#
# This replaces the older `Tool(...)` wrapper from earlier versions of LangChain.

# %%
@tool
def get_share_price(symbol: str) -> float:
    """Return the current share price for a given ticker symbol."""
    fake_prices = {"AAPL": 241.5, "GOOG": 168.2, "AMZN": 198.0}
    return fake_prices.get(symbol.upper(), 0.0)

print("name:", get_share_price.name)
print("description:", get_share_price.description)
print("args:", get_share_price.args)
print("called directly:", get_share_price.invoke({"symbol": "AAPL"}))
# Out:
# name: get_share_price
# description: Return the current share price for a given ticker symbol.
# args: {'symbol': {'title': 'Symbol', 'type': 'string'}}
# called directly: 241.5

# %% [markdown]
# ### Giving tools to the model
#
# This is a bit clunky; redemption will come in Day 3 when we use the create_agent features,
#
# For now, we have to write the loop ourselves, rather like we did in Week 1.
#
# The first step is to bind the tools to the model with `bind_tools`. Now when we invoke, the model may come back not with an answer but with a request to run a tool. That request shows up in `.tool_calls`.

# %%
llm_with_tools = llm.bind_tools([get_share_price])

response = llm_with_tools.invoke("What is the share price of Amazon?")
print("content:", repr(response.content))
print("tool_calls:", response.tool_calls)
# Out:
# content: ''
# tool_calls: [{'name': 'get_share_price', 'args': {'symbol': 'AMZN'}, 'id': 'call_KTrvWz6LD5ro9d95mEykiJWc', 'type': 'tool_call'}]

# %% [markdown]
# ### Running the tool loop by hand
#
# So now we need to write a little loop, quite similar to Week 1

# %%
# Start the conversation and keep the model's tool request in the history
conversation = [HumanMessage("What is the share price of Amazon?")]
ai_message = llm_with_tools.invoke(conversation)
conversation.append(ai_message)

# Run each requested tool and add its result as a ToolMessage
for call in ai_message.tool_calls:
    if call["name"] == "get_share_price":
        result = get_share_price.invoke(call["args"])
        conversation.append(ToolMessage(content=str(result), tool_call_id=call["id"]))

# Invoke again, now that the model can see the tool result
final = llm_with_tools.invoke(conversation)
print(final.content)
# Out:
# Amazon (AMZN) is at **$198.00** per share.

# %% [markdown]
# ### Structured output
#
# Similar to OpenAI Agents SDK, we can require the model to respond with a Pydantic subclass

# %%
class Company(BaseModel):
    name: str = Field(description="The company name")
    ticker: str = Field(description="The stock ticker symbol")
    founded_year: int = Field(description="The year the company was founded")

structured_llm = llm.with_structured_output(Company)

company = structured_llm.invoke("Tell me about Amazon the technology company")
print(company)
print("Just the ticker:", company.ticker)
# Out:
# name='Amazon' ticker='AMZN' founded_year=1994
# Just the ticker: AMZN

# %% [markdown]
# ## That is Layer 1
#
# It's like a more rich and more involved version of LiteLLM.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Write a second tool of your own, perhaps one that looks up a fictional weather report for a city. Bind both tools to the model and ask a question that needs both, then run the tool loop by hand until the model gives a final answer. It will feel more gritty than OpenAI Agents SDK or CrewAI.
#             We will fix that by Day 3!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
@tool
def get_weight(age: int):
    """It returns an estimated weight for a given age."""
    fake_weights = {40: 230, 20: 149, 30: 180}
    return fake_weights.get(age, 0)

# %%
llm_with_tools_ex = llm.bind_tools([get_weight])

response = llm_with_tools_ex.invoke("What is my weight? my age is 40")
print("content:", repr(response.content))
print("tool_calls:", response.tool_calls)
# Out:
# content: ''
# tool_calls: [{'name': 'get_weight', 'args': {'age': 40}, 'id': 'call_68fMEu951NVzf9WhXryGrmao', 'type': 'tool_call'}]

# %%
tool_call = response.tool_calls[0]
result = get_weight.invoke(tool_call["args"])
print(result)
# Out:
# 230
