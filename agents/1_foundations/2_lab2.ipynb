# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. See Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> for how to set up a separate project for your work.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...<br/>And if you post about it on LinkedIn and tag me, then I'll weigh in to amplify your achievement. If you see other students posting, please give them your encouragement too.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask the Cursor Agent to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}") 
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
request = """
Please come up with a challenging, nuanced question with a succinct answer,
that I can ask a number of LLMs to evaluate their intelligence.
Not a mathematical puzzle, but more of a thought-provoking question that requires intelligent insight.
Include in your question that the answer must be short.
"""
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': '\nPlease come up with a challenging, nuanced question with a succinct answer,\nthat I can ask a number of LLMs to evaluate their intelligence.\nNot a mathematical puzzle, but more of a thought-provoking question that requires intelligent insight.\nInclude in your question that the answer must be short.\nAnswer only with the question, no explanation.'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
display(Markdown(question))
# Out:
# A country must choose one policy to reduce traffic deaths: lower speed limits, invest in safer roads, or enforce stricter driver penalties. Which is likely the most effective overall, and why? Answer in one or two sentences.

# %% [markdown]
# ## Calling LLMs from multple providers
#
# We are about to call LLMs from many other providers.
# They all provide API endpoints that are compatible with OpenAI, as explained in Guide 9 in the guides folder.
# So we can simply use these endpoints as if we are using OpenAI.
#
# Please note:
#
# I'm going to use lots of LLMs from different providers, but you don't need to! This is only to show their abilities.

# %%
# OpenAI Compatible URLs

ANTHROPIC_BASE_URL = "https://api.anthropic.com/v1/"
DEEPSEEK_BASE_URL = "https://api.deepseek.com/v1"
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
GROQ_BASE_URL = "https://api.groq.com/openai/v1"
GROK_BASE_URL = "https://api.x.ai/v1"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
# OpenAI client libraries with the right base_url and key
# If this surprises you, please see Guide 9 in the Guides folder!

anthropic = OpenAI(api_key=anthropic_api_key, base_url=ANTHROPIC_BASE_URL)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=DEEPSEEK_BASE_URL)
gemini = OpenAI(api_key=google_api_key, base_url=GEMINI_BASE_URL)
groq = OpenAI(api_key=groq_api_key, base_url=GROQ_BASE_URL)
grok = OpenAI(api_key=grok_api_key, base_url=GROK_BASE_URL)
openrouter = OpenAI(api_key=openrouter_api_key, base_url=OPENROUTER_BASE_URL)
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
def record(model_name, answer):
    competitors.append(model_name)
    answers.append(answer)
    display(Markdown(answer))

# %%
# The API we know well
# Reasoning effort can be none, low, medium, high, or xhigh

model_name = "gpt-5.4-nano"

response = openai.chat.completions.create(model=model_name, messages=messages, reasoning_effort="none")
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# Most likely **investing in safer roads** is the most effective overall, because engineering changes (median barriers, better lighting/signage, traffic calming, safer intersections) reduce the chance and severity of crashes for all drivers, including those who make mistakes. Speed limits or penalties can help, but their impact is more dependent on compliance and enforcement, and they don’t directly fix hazardous infrastructure.

# %%
model_name = "claude-sonnet-4-6"

response = anthropic.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# Investing in safer roads (e.g., better barriers, lighting, intersection design) is likely most effective overall because it reduces crash severity for *all* drivers regardless of behavior, addressing the physical environment rather than relying on compliance with laws or individual responsiveness to penalties.

# %%
model_name = "gemini-3.1-flash-lite"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# Investing in safer road infrastructure is generally considered the most effective policy because it creates a forgiving environment that reduces the likelihood and severity of accidents regardless of human error. Unlike speed limits or penalties, which rely on behavioral compliance, physical improvements—such as roundabouts, medians, and protected lanes—provide consistent, permanent safety benefits.

# %%
model_name = "deepseek-v4-flash"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[51], line 3
#       1 model_name = "deepseek-v4-flash"
#       2
# ----> 3 response = deepseek.chat.completions.create(model=model_name, messages=messages)
#       4 answer = response.choices[0].message.content
#       5
#       6 record(model_name, answer)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Authentication Fails, Your api key: ****EeIA is invalid', 'type': 'authentication_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[52], line 3
#       1 model_name = "openai/gpt-oss-120b"
#       2
# ----> 3 response = groq.chat.completions.create(model=model_name, messages=messages)
#       4 answer = response.choices[0].message.content
#       5
#       6 display(Markdown(answer))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %%
model_name = "moonshotai/kimi-k2.6"

response = openrouter.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[54], line 3
#       1 model_name = "moonshotai/kimi-k2.6"
#       2
# ----> 3 response = openrouter.chat.completions.create(model=model_name, messages=messages)
#       4 answer = response.choices[0].message.content
#       5
#       6 record(model_name, answer)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">Many models on Ollama are FAR too large for your home computer. Be sure to browse the models on the Ollama website. Look to use models that are size 3GB or less unless you know better; llama3.2 is a great first choice. Don't pick models that end in :cloud; that's something different (a cloud inference service, like Groq).
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 249 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 315 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 633 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.6 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.6 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3
MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 178 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  6.6 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 185 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  6.6 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  6.6 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 191 MB/2.0 GB  6.7 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 192 MB/2.0 GB  6.7 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 192 MB/2.0 GB  6.7 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  6.7 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  6.7 MB/s   4m32spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  6.6 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  6.6 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  6.6 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  6.6 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 207 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB  6.6 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB  6.6 MB/s   4m33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 210 MB/2.0 GB  6.5 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  6.5 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 212 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  6.5 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  6.6 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 221 MB/2.0 GB  6.6 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 221 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 221 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 224 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 232 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 235 MB/2.0 GB  6.4 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 238 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 239 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 239 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 240 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  6.4 MB/s   4m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  6.3 MB/s   4m40spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 243 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 243 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 244 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 246 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  6.3 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 248 MB/2.0 GB  6.3 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 252 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 252 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  6.3 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  6.2 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 254 MB/2.0 GB  6.2 MB/s   4m43spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 256 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 257 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 260 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 261 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 261 MB/2.0 GB  6.2 MB/s   4m42spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  6.4 MB/s   4m36spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 263 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 264 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 264 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 268 MB/2.0 GB  6.4 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 272 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  6.5 MB/s   4m27spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  6.5 MB/s   4m26spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 275 MB/2.0 GB  6.6 MB/s   4m26spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 276 MB/2.0 GB  6.6 MB/s   4m26spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 279 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 280 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 280 MB/2.0 GB  6.6 MB/s   4m25spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 281 MB/2.0 GB  6.6 MB/s   4m23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 282 MB/2.0 GB  6.6 MB/s   4m23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 282 MB/2.0 GB  6.6 MB/s   4m23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 283 MB/2.0 GB  6.6 MB/s   4m23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 284 MB/2.0 GB  6.6 MB/s   4m23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 284 MB/2.0 GB  6.6 MB/s   4m22spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 285 MB/2.0 GB  6.6 MB/s   4m22spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 285 MB/2.0 GB  6.6 MB/s   4m22spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  6.6 MB/s   4m22spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  6.6 MB/s   4m22spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 287 MB/2.0 GB  6.5 MB/s   4m24spulling manifest
# ...
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.7 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.5 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      1spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  5.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.9 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.5 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.5 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  4.5 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# verifying sha256 digest
# writing manifest
# success

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.5.1-cp312-cp312-win_amd64.whl.metadata (46 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\repos\ai-engineer-agentic-track-TheCompleteAgentAndMCPCourse\.venv\Lib\site-packages (from requests) (2.7.0)
# Collecting certifi>=2023.5.7 (from requests)
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.5.1-cp312-cp312-win_amd64.whl (200 kB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# Installing collected packages: charset_normalizer, certifi, requests
#
#    ---------------------------------------- 0/3 [charset_normalizer]
#    ------------- -------------------------- 1/3 [certifi]
#    -------------------------- ------------- 2/3 [requests]
#    ---------------------------------------- 3/3 [requests]
#
# Successfully installed certifi-2026.7.22 charset_normalizer-3.5.1 requests-2.34.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
requests.get('http://localhost:11434').content
# Out:
# b'Ollama is running'

# %%
import requests
models = requests.get('http://localhost:11434/v1/models').json()
for model in models.get("data"):
    print(model.get("id"))

# %%
model_name = "llama3.2:1b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)

# %%
model_name = "gpt-oss:latest"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
model_name = "gemma4:latest"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(len(competitors))
print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %% [markdown]
# ## And now for Grok!
#
# Branded as "The most truth-seeking large language model in the world".. so let's use it as our LLM as a judge

# %%
# Judgement time!
# Grok is "The most truth-seeking large language model in the world."

model_name = "grok-4.3"

response = grok.chat.completions.create(model=model_name, messages=judge_messages)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
